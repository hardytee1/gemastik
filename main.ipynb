# %%
dev = "AIzaSyAJGxa6ZCua3nJkrW-8WQuWkxfLjr1njmo"
idbanget = "fRoJ2VpzJPI"

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId=idbanget,
    maxResults=3000
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId=idbanget, maxResults=3000, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      11 non-null     object
#  1   updated_at  11 non-null     object
#  2   like_count  11 non-null     int64
#  3   text        11 non-null     object
#  4   public      11 non-null     bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 495.0+ bytes

# %%
df.head(10)
# Out:
#                 author            updated_at  like_count  \
# 0         @dapdapstuff  2024-05-28T08:32:22Z           0
# 1  @sodiqhariyanto8705  2024-05-10T06:11:50Z           2
# 2    @asepdjunaedy9382  2024-04-03T23:44:43Z           0
# 3          @royandoang  2024-03-29T08:27:42Z           1
# 4     @user-sr6fl6km4v  2024-03-19T18:21:32Z           0
# 5   @ahmadgusmanto1281  2024-03-17T01:52:23Z           1
# 6     @user-nu3qe2yz2b  2024-03-14T10:36:33Z           0
# 7       @virgoleighton  2024-03-05T02:15:32Z           1
# 8           @m3jozz377  2024-03-01T09:48:58Z           2
# 9    @luckymanuell1810  2024-02-16T13:36:40Z           2
#
#                                                 text  public
# 0                                      Ruwet juga ya    True
# 1  Saya sudah mencoba Kereta Cepat Whoosh memang ...    True
# 2  Ga efektif klw mengejar waktu atau sebaliknya ...    True
# 3  Hmmm..jadi kesimpulannya  nih, kalau  berangka...    True
# ...

# %%
selected_columns = df[['author', 'updated_at', 'like_count', 'text','public']]
selected_columns.reset_index(inplace=False)
selected_columns.to_excel('DATA/30_11.xlsx', index=False)
